# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
import pandas as pd
from sklearn.model_selection import cross_validate, KFold
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, ExtraTreesClassifier, \
    VotingClassifier, StackingClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.compose import make_column_transformer
from sklearn.compose import make_column_selector as selector
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder

#Load the dataset
df = pd.read_csv('german_credit_data.csv')

# Drop unnecessary columns
df.drop(['Sex', 'Job', 'Credit amount'], axis=1, inplace=True)

# Convert categorical variables to numerical form using label encoding
le = LabelEncoder()
#df['Sex'] = le.fit_transform(df['Sex'])
df['Housing'] = le.fit_transform(df['Housing'])
df['Risk'] = le.fit_transform(df['Risk'])
df['Saving accounts'] = le.fit_transform(df['Saving accounts'])
df['Checking account'] = le.fit_transform(df['Checking account'])
df['Purpose'] = le.fit_transform(df['Purpose'])

X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Define the classifiers
ada_boost = AdaBoostClassifier(n_estimators=10,
                                        random_state=42)

gradient_boost = GradientBoostingClassifier(n_estimators=10,
                                        random_state=42)

xg_boost = xgb.XGBClassifier(n_estimators=10,
                                        random_state=42)


cat_boost = CatBoostClassifier(n_estimators=10,
                                        random_state=42)


# Define the cross-validation
cv = KFold(n_splits=10, random_state=42, shuffle=True)

# Define the scoring metrics
scoring = ['accuracy', 'f1', 'precision', 'recall']

# Perform cross-validation and print the results
for clf, name in [(ada_boost, 'Ada Boost'),
                  (gradient_boost, 'Gradient Boost'),
                 (xg_boost, 'Xg Boost'),
                  (cat_boost, 'Cat Boost')]:

    results = cross_validate(clf, X, y, cv=cv, scoring=scoring)

    accuracy = results['test_accuracy'].mean()
    f1 = results['test_f1'].mean()
    precision = results['test_precision'].mean()
    recall = results['test_recall'].mean()

    print(f'{name}:')
    print(f'Accuracy: {accuracy:.4f}')
    print(f'F1 Score: {f1:.4f}')
    print(f'Precision: {precision:.4f}')
    print(f'Recall: {recall:.4f}')
    print('-' * 50)
# Out:
# Ada Boost:
# Accuracy: 0.7140
# F1 Score: 0.8046
# Precision: 0.7652
# Recall: 0.8502
# --------------------------------------------------
# Gradient Boost:
# Accuracy: 0.7190
# F1 Score: 0.8273
# Precision: 0.7248
# Recall: 0.9661
# --------------------------------------------------
# Xg Boost:
# Accuracy: 0.7130
# F1 Score: 0.8047
# Precision: 0.7636
# Recall: 0.8519
# --------------------------------------------------
# Learning rate set to 0.5
# 0:	learn: 0.6107359	total: 1.05ms	remaining: 9.43ms
# 1:	learn: 0.5660688	total: 1.94ms	remaining: 7.76ms
# 2:	learn: 0.5360093	total: 2.86ms	remaining: 6.67ms
# 3:	learn: 0.5174244	total: 3.65ms	remaining: 5.47ms
# 4:	learn: 0.5009346	total: 4.6ms	remaining: 4.6ms
# 5:	learn: 0.4925795	total: 5.5ms	remaining: 3.67ms
# 6:	learn: 0.4839312	total: 6.34ms	remaining: 2.71ms
# 7:	learn: 0.4720621	total: 7.23ms	remaining: 1.81ms
# 8:	learn: 0.4640463	total: 8.04ms	remaining: 892us
# 9:	learn: 0.4576858	total: 8.77ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.6003526	total: 1.33ms	remaining: 12ms
# 1:	learn: 0.5550561	total: 2.09ms	remaining: 8.36ms
# 2:	learn: 0.5245884	total: 2.97ms	remaining: 6.92ms
# 3:	learn: 0.5076213	total: 4.39ms	remaining: 6.58ms
# 4:	learn: 0.4957699	total: 5.09ms	remaining: 5.09ms
# 5:	learn: 0.4852769	total: 6.06ms	remaining: 4.04ms
# 6:	learn: 0.4765188	total: 7.03ms	remaining: 3.01ms
# 7:	learn: 0.4748246	total: 7.33ms	remaining: 1.83ms
# 8:	learn: 0.4688507	total: 8.14ms	remaining: 904us
# 9:	learn: 0.4614073	total: 9.22ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.5990540	total: 1.29ms	remaining: 11.7ms
# 1:	learn: 0.5525309	total: 2.06ms	remaining: 8.26ms
# 2:	learn: 0.5255419	total: 3.01ms	remaining: 7.02ms
# 3:	learn: 0.5058644	total: 3.9ms	remaining: 5.85ms
# 4:	learn: 0.4920747	total: 4.71ms	remaining: 4.71ms
# 5:	learn: 0.4831844	total: 5.58ms	remaining: 3.72ms
# 6:	learn: 0.4760783	total: 6.55ms	remaining: 2.81ms
# 7:	learn: 0.4662758	total: 7.33ms	remaining: 1.83ms
# 8:	learn: 0.4578941	total: 8.12ms	remaining: 902us
# 9:	learn: 0.4508546	total: 9.16ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.6053740	total: 936us	remaining: 8.43ms
# 1:	learn: 0.5615614	total: 1.67ms	remaining: 6.66ms
# 2:	learn: 0.5281119	total: 2.34ms	remaining: 5.46ms
# 3:	learn: 0.5139320	total: 3.01ms	remaining: 4.51ms
# 4:	learn: 0.5012743	total: 3.67ms	remaining: 3.67ms
# 5:	learn: 0.4918038	total: 4.33ms	remaining: 2.88ms
# 6:	learn: 0.4836979	total: 4.99ms	remaining: 2.14ms
# 7:	learn: 0.4815727	total: 5.24ms	remaining: 1.31ms
# 8:	learn: 0.4745677	total: 5.9ms	remaining: 655us
# 9:	learn: 0.4669842	total: 6.55ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.6033696	total: 850us	remaining: 7.65ms
# 1:	learn: 0.5570051	total: 1.55ms	remaining: 6.2ms
# 2:	learn: 0.5253232	total: 2.21ms	remaining: 5.17ms
# 3:	learn: 0.5098600	total: 2.87ms	remaining: 4.31ms
# 4:	learn: 0.4966274	total: 3.54ms	remaining: 3.54ms
# 5:	learn: 0.4842820	total: 4.19ms	remaining: 2.79ms
# 6:	learn: 0.4790102	total: 4.86ms	remaining: 2.08ms
# 7:	learn: 0.4677204	total: 5.53ms	remaining: 1.38ms
# 8:	learn: 0.4578888	total: 6.19ms	remaining: 687us
# 9:	learn: 0.4504902	total: 6.86ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.6022681	total: 859us	remaining: 7.73ms
# 1:	learn: 0.5535597	total: 1.56ms	remaining: 6.26ms
# 2:	learn: 0.5212900	total: 2.23ms	remaining: 5.21ms
# 3:	learn: 0.5042314	total: 2.89ms	remaining: 4.33ms
# 4:	learn: 0.4866604	total: 3.55ms	remaining: 3.55ms
# 5:	learn: 0.4757846	total: 4.21ms	remaining: 2.81ms
# 6:	learn: 0.4681352	total: 4.88ms	remaining: 2.09ms
# 7:	learn: 0.4585599	total: 5.54ms	remaining: 1.38ms
# 8:	learn: 0.4508308	total: 6.21ms	remaining: 690us
# 9:	learn: 0.4413918	total: 6.87ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.6045895	total: 891us	remaining: 8.02ms
# 1:	learn: 0.5620600	total: 1.6ms	remaining: 6.39ms
# 2:	learn: 0.5327182	total: 2.27ms	remaining: 5.31ms
# 3:	learn: 0.5186043	total: 2.95ms	remaining: 4.42ms
# 4:	learn: 0.5008194	total: 3.6ms	remaining: 3.6ms
# 5:	learn: 0.4907978	total: 4.27ms	remaining: 2.85ms
# 6:	learn: 0.4857039	total: 4.62ms	remaining: 1.98ms
# 7:	learn: 0.4801698	total: 5.37ms	remaining: 1.34ms
# 8:	learn: 0.4708274	total: 6.14ms	remaining: 682us
# 9:	learn: 0.4676617	total: 6.89ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.5976671	total: 907us	remaining: 8.17ms
# 1:	learn: 0.5564288	total: 1.65ms	remaining: 6.61ms
# 2:	learn: 0.5270197	total: 2.34ms	remaining: 5.47ms
# 3:	learn: 0.5059196	total: 3.02ms	remaining: 4.54ms
# 4:	learn: 0.4914489	total: 3.68ms	remaining: 3.68ms
# 5:	learn: 0.4833042	total: 4.36ms	remaining: 2.9ms
# 6:	learn: 0.4756528	total: 5.03ms	remaining: 2.16ms
# 7:	learn: 0.4638874	total: 5.71ms	remaining: 1.43ms
# 8:	learn: 0.4573701	total: 6.42ms	remaining: 713us
# 9:	learn: 0.4512005	total: 7.16ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.6019541	total: 843us	remaining: 7.59ms
# 1:	learn: 0.5561279	total: 1.55ms	remaining: 6.19ms
# 2:	learn: 0.5279166	total: 2.21ms	remaining: 5.15ms
# 3:	learn: 0.5106871	total: 2.85ms	remaining: 4.28ms
# 4:	learn: 0.4961351	total: 3.51ms	remaining: 3.51ms
# 5:	learn: 0.4859304	total: 4.15ms	remaining: 2.77ms
# 6:	learn: 0.4808513	total: 4.81ms	remaining: 2.06ms
# 7:	learn: 0.4714091	total: 5.47ms	remaining: 1.37ms
# 8:	learn: 0.4641594	total: 6.13ms	remaining: 681us
# 9:	learn: 0.4575028	total: 6.78ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.6048235	total: 838us	remaining: 7.54ms
# 1:	learn: 0.5594008	total: 1.53ms	remaining: 6.13ms
# 2:	learn: 0.5298216	total: 2.21ms	remaining: 5.16ms
# 3:	learn: 0.5097243	total: 2.88ms	remaining: 4.32ms
# 4:	learn: 0.4982521	total: 3.54ms	remaining: 3.54ms
# 5:	learn: 0.4878002	total: 4.24ms	remaining: 2.83ms
# 6:	learn: 0.4778210	total: 4.92ms	remaining: 2.11ms
# 7:	learn: 0.4673550	total: 5.59ms	remaining: 1.4ms
# 8:	learn: 0.4542896	total: 6.25ms	remaining: 694us
# 9:	learn: 0.4491507	total: 6.91ms	remaining: 0us
# Cat Boost:
# Accuracy: 0.7390
# F1 Score: 0.8259
# Precision: 0.7748
# Recall: 0.8864
# --------------------------------------------------
