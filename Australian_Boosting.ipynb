# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
import pandas as pd
from sklearn.model_selection import cross_validate, KFold
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, ExtraTreesClassifier, \
    VotingClassifier, StackingClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.compose import make_column_transformer
from sklearn.compose import make_column_selector as selector
import xgboost as xgb

# Load the dataset
df = pd.read_csv('australian.dat', sep=' ', header=None)
df.drop([0, 3, 5, 6, 8, 9], axis=1, inplace=True)

X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Define the classifiers
ada_boost = AdaBoostClassifier(n_estimators=10,
                                        random_state=42)

gradient_boost = GradientBoostingClassifier(n_estimators=10,
                                        random_state=42)

xg_boost = xgb.XGBClassifier(n_estimators=10,
                                        random_state=42)


cat_boost = CatBoostClassifier(n_estimators=10,
                                        random_state=42)


# Define the cross-validation
cv = KFold(n_splits=10, random_state=42, shuffle=True)

# Define the scoring metrics
scoring = ['accuracy', 'f1', 'precision', 'recall']

# Perform cross-validation and print the results
for clf, name in [(ada_boost, 'Ada Boost'),
                  (gradient_boost, 'Gradient Boost'),
                 (xg_boost, 'Xg Boost'),
                  (cat_boost, 'Cat Boost')]:

    results = cross_validate(clf, X, y, cv=cv, scoring=scoring)

    accuracy = results['test_accuracy'].mean()
    f1 = results['test_f1'].mean()
    precision = results['test_precision'].mean()
    recall = results['test_recall'].mean()

    print(f'{name}:')
    print(f'Accuracy: {accuracy:.4f}')
    print(f'F1 Score: {f1:.4f}')
    print(f'Precision: {precision:.4f}')
    print(f'Recall: {recall:.4f}')
    print('-' * 50)
# Out:
# Ada Boost:
# Accuracy: 0.8522
# F1 Score: 0.8313
# Precision: 0.8232
# Recall: 0.8439
# --------------------------------------------------
# Gradient Boost:
# Accuracy: 0.8580
# F1 Score: 0.8437
# Precision: 0.8148
# Recall: 0.8765
# --------------------------------------------------
# Xg Boost:
# Accuracy: 0.8565
# F1 Score: 0.8414
# Precision: 0.8185
# Recall: 0.8670
# --------------------------------------------------
# Learning rate set to 0.5
# 0:	learn: 0.4927494	total: 603us	remaining: 5.43ms
# 1:	learn: 0.4134784	total: 1.82ms	remaining: 7.3ms
# 2:	learn: 0.3714139	total: 2.79ms	remaining: 6.51ms
# 3:	learn: 0.3400843	total: 3.56ms	remaining: 5.33ms
# 4:	learn: 0.3114812	total: 5.21ms	remaining: 5.21ms
# 5:	learn: 0.2927197	total: 6ms	remaining: 4ms
# 6:	learn: 0.2772985	total: 6.87ms	remaining: 2.94ms
# 7:	learn: 0.2649769	total: 8.44ms	remaining: 2.11ms
# 8:	learn: 0.2572967	total: 9.16ms	remaining: 1.02ms
# 9:	learn: 0.2515569	total: 10.7ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.4920970	total: 503us	remaining: 4.53ms
# 1:	learn: 0.4167738	total: 1.57ms	remaining: 6.29ms
# 2:	learn: 0.3774942	total: 2.46ms	remaining: 5.73ms
# 3:	learn: 0.3496542	total: 2.91ms	remaining: 4.37ms
# 4:	learn: 0.3301019	total: 3.9ms	remaining: 3.9ms
# 5:	learn: 0.3176024	total: 4.76ms	remaining: 3.17ms
# 6:	learn: 0.3074642	total: 5.73ms	remaining: 2.46ms
# 7:	learn: 0.2907354	total: 6.74ms	remaining: 1.69ms
# 8:	learn: 0.2817247	total: 7.7ms	remaining: 855us
# 9:	learn: 0.2759143	total: 8.8ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0
ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.4959105	total: 467us	remaining: 4.21ms
# 1:	learn: 0.4177940	total: 1.2ms	remaining: 4.81ms
# 2:	learn: 0.3755086	total: 1.94ms	remaining: 4.53ms
# 3:	learn: 0.3464443	total: 2.65ms	remaining: 3.97ms
# 4:	learn: 0.3230558	total: 3.37ms	remaining: 3.37ms
# 5:	learn: 0.3063877	total: 4.12ms	remaining: 2.74ms
# 6:	learn: 0.2954832	total: 4.81ms	remaining: 2.06ms
# 7:	learn: 0.2835676	total: 5.5ms	remaining: 1.37ms
# 8:	learn: 0.2792591	total: 6.16ms	remaining: 684us
# 9:	learn: 0.2727983	total: 6.86ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.4963611	total: 520us	remaining: 4.69ms
# 1:	learn: 0.4175636	total: 1.45ms	remaining: 5.81ms
# 2:	learn: 0.3754591	total: 2.2ms	remaining: 5.13ms
# 3:	learn: 0.3392319	total: 2.94ms	remaining: 4.4ms
# 4:	learn: 0.3134528	total: 3.71ms	remaining: 3.71ms
# 5:	learn: 0.2956250	total: 4.4ms	remaining: 2.94ms
# 6:	learn: 0.2764076	total: 5.16ms	remaining: 2.21ms
# 7:	learn: 0.2695240	total: 5.91ms	remaining: 1.48ms
# 8:	learn: 0.2645683	total: 6.62ms	remaining: 735us
# 9:	learn: 0.2548903	total: 7.34ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.4897451	total: 472us	remaining: 4.25ms
# 1:	learn: 0.4116599	total: 1.21ms	remaining: 4.83ms
# 2:	learn: 0.3710813	total: 1.88ms	remaining: 4.4ms
# 3:	learn: 0.3339347	total: 2.57ms	remaining: 3.85ms
# 4:	learn: 0.3126443	total: 3.21ms	remaining: 3.21ms
# 5:	learn: 0.3019422	total: 3.86ms	remaining: 2.57ms
# 6:	learn: 0.2849869	total: 4.53ms	remaining: 1.94ms
# 7:	learn: 0.2773560	total: 5.17ms	remaining: 1.29ms
# 8:	learn: 0.2719400	total: 5.82ms	remaining: 647us
# 9:	learn: 0.2652697	total: 6.5ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.4920187	total: 463us	remaining: 4.17ms
# 1:	learn: 0.4130927	total: 1.21ms	remaining: 4.86ms
# 2:	learn: 0.3705196	total: 2.01ms	remaining: 4.68ms
# 3:	learn: 0.3385708	total: 2.75ms	remaining: 4.12ms
# 4:	learn: 0.3115000	total: 3.48ms	remaining: 3.48ms
# 5:	learn: 0.2974137	total: 4.17ms	remaining: 2.78ms
# 6:	learn: 0.2867441	total: 4.86ms	remaining: 2.08ms
# 7:	learn: 0.2800829	total: 5.61ms	remaining: 1.4ms
# 8:	learn: 0.2734982	total: 6.32ms	remaining: 702us
# 9:	learn: 0.2695185	total: 7.3ms	remaining: 0us
# Cat Boost:
# Accuracy: 0.8754
# F1 Score: 0.8612
# Precision: 0.8393
# Recall: 0.8859
# --------------------------------------------------
